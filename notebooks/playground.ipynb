# %%
from weibo_scraper import get_weibo_profile
from weibo_scraper import get_weibo_tweets
from weibo_scraper import get_weibo_tweets_by_name
from weibo_scraper import get_formatted_weibo_tweets_by_name

# %%
weibo_profile = get_weibo_profile(name='xiaolwl',)

# %%
weibo_profile
# Out:
# <UserMeta uid=1139098205 , screen_name='xiaolwl' , description='眼科医生' , gender='m' , avatar_hd='https://ww4.sinaimg.cn/orj480/43e5425djw1e8qgp5bmzyj2050050aa8.jpg' ,profile_image_url = 'https://tva4.sinaimg.cn/crop.0.0.180.180.180/43e5425djw1e8qgp5bmzyj2050050aa8.jpg?KID=imgbed,tva&Expires=1666375488&ssig=OLLxErXTtw'>

# %%
weibo_profile.description
# Out:
# '眼科医生'

# %%
for tweet in get_weibo_tweets_by_name(name='xiaolwl', pages=1):
    print(tweet)
# Out:
# {'card_type': 9, 'profile_type_id': 'proweibo_4467107636950632', 'itemid': '1076031139098205_-_4467107636950632', 'scheme': 'https://m.weibo.cn/status/Is9M7taaY?mblogid=Is9M7taaY&luicode=10000011&lfid=1076031139098205', 'mblog': {'visible': {'type': 0, 'list_id': 0}, 'created_at': 'Sat Feb 01 10:41:58 +0800 2020', 'id': '4467107636950632', 'mid': '4467107636950632', 'can_edit': False, 'show_additional_indication': 0, 'text': '今天核酸检测结果阳性，尘埃落定，终于确诊了<span class="url-icon"><img alt=[二哈] src="https://h5.sinaimg.cn/m/emoticon/icon/others/d_erha-139d0e07bd.png" style="width:1em; height:1em;" /></span> <a  href="http://weibo.com/p/100101B2094757D069A7FF469B" data-hide=""><span class=\'url-icon\'><img style=\'width: 1rem;height: 1rem\' src=\'https://h5.sinaimg.cn/upload/2015/09/25/3/timeline_card_small_location_default.png\'></span><span class="surl-text">武汉·武汉市中心医院</span></a> ', 'textLength': 68, 'source': 'iPhone客户端', 'favorited': False, 'pic_ids': [], 'is_paid': False, 'mblog_vip_type': 0,
# ...

# %%
result_iterator = get_formatted_weibo_tweets_by_name(name='xiaolwl', pages=3)
for user_meta in result_iterator:
    if user_meta is not None:
        for tweetMeta in user_meta.cards_node:
            print(tweetMeta.mblog.text)
# Out:
# 今天核酸检测结果阳性，尘埃落定，终于确诊了<span class="url-icon"><img alt=[二哈] src="https://h5.sinaimg.cn/m/emoticon/icon/others/d_erha-139d0e07bd.png" style="width:1em; height:1em;" /></span> <a  href="http://weibo.com/p/100101B2094757D069A7FF469B" data-hide=""><span class='url-icon'><img style='width: 1rem;height: 1rem' src='https://h5.sinaimg.cn/upload/2015/09/25/3/timeline_card_small_location_default.png'></span><span class="surl-text">武汉·武汉市中心医院</span></a>
# 大家好，我是武汉市中心医院眼科医生李文亮。12月30日，我看到一份病人的检测报告，检出SARS冠状病毒高置信度阳性指标，出于提醒同学注意防护的角度，因为我同学也都是临床医生，所以在群里发布了消息说“确诊了7例SARS”。消息发出后，1月3日，公安局找到我并签了训诫书。之后我一直正常工作，在接诊 ...<a href="/status/4466768535861595">全文</a>
# 转发微博
# ...
